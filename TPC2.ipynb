# %%
def procbin():
    print("Pense num número entre 1 e 100")
    n=50       # sofre a soma/subtração
    nlinha=50  # sofre a divisão
    encontrado = False
    i=1
    while not encontrado: 
        j=input("O seu número é < ou > ou = a " + str(n) + "?")
        if (i<7):
            if (i==6):
                nlinha=2
            if (i==5):
                nlinha=4
            if (j=="<"):
                nlinha=(nlinha//2)
                n=(n-nlinha)
                i=i+1
            elif (j==">"):
                nlinha=(nlinha//2)
                n=(n+nlinha)
                i=i+1
            elif (j=="="):
                encontrado=True
                print(str(n) + " foi encontrado em " + str(i) + " tentativas")

            else:
                print("Por favor introduza um caracter válido!")
                j=input("O seu número é < ou > ou = a " + str(n) + "?")
        else:
            encontrado=True
            print("O jogador mentiu")
            
procbin()
# Out:
# Pense num número entre 1 e 100
# O seu número é < ou > ou = a 50?>
# O seu número é < ou > ou = a 75?>
# O seu número é < ou > ou = a 87?>
# O seu número é < ou > ou = a 93?<
# O seu número é < ou > ou = a 90?<
# O seu número é < ou > ou = a 88?<
# O seu número é < ou > ou = a 87?<
# O jogador mentiu
